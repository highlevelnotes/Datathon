# %%
import pandas as pd

# 주어진 데이터를 딕셔너리로 정의
data = {
    "Model": ["LogisticRegression", "Naive Bayes", "GradientBoosting", "LightGBM",
              "RandomForest", "DecisionTree", "XGBoost"],
    "TPR at FPR=5%": ["48.54%", "43.26%", "32.97%", "25.96%", "24.7%", "0.0%", "0.0%"],
    "Fairness Predictive Equality": ["73.03%", "65.93%", "99.94%", "99.98%", "100.0%", "97.9%", "100.0%"]
}

# 데이터프레임 생성
oversampled = pd.DataFrame(data)

# 결과 출력
oversampled
# Out:
#                 Model TPR at FPR=5% Fairness Predictive Equality
# 0  LogisticRegression        48.54%                       73.03%
# 1         Naive Bayes        43.26%                       65.93%
# 2    GradientBoosting        32.97%                       99.94%
# 3            LightGBM        25.96%                       99.98%
# 4        RandomForest         24.7%                       100.0%
# 5        DecisionTree          0.0%                        97.9%
# 6             XGBoost          0.0%                       100.0%

# %%
# 주어진 데이터를 딕셔너리로 정의
data = {
    "Model": ["LightGBM", "XGBoost", "Logistic Regression", "Naive Bayes",
              "Decision Tree", "RandomForest", "Gradient Boosting"],
    "TPR at FPR=5%": ["53.65%", "50.45%", "49.69%", "37.84%", "0%", "0%", "53.37%"],
    "Fairness Predictive Equality": ["29.18%", "28.05%", "89.52%", "44.00%", "38.56%", "37.13%", "27.02%"]
}

# 데이터프레임 생성
original = pd.DataFrame(data)

# 결과 출력
original
# Out:
#                  Model TPR at FPR=5% Fairness Predictive Equality
# 0             LightGBM        53.65%                       29.18%
# 1              XGBoost        50.45%                       28.05%
# 2  Logistic Regression        49.69%                       89.52%
# 3          Naive Bayes        37.84%                       44.00%
# 4        Decision Tree            0%                       38.56%
# 5         RandomForest            0%                       37.13%
# 6    Gradient Boosting        53.37%                       27.02%

# %%
# 주어진 데이터를 딕셔너리로 정의
data = {
    "Model": ["Logistic Regression", "Random Forest", "Gradient Boosting", "Decision Tree",
              "Naive Bayes", "LightGBM", "XGBoost"],
    "TPR at FPR=5%": ["49.69%", "44.96%", "52.05%", "0.00%", "33.95%", "52.68%", "47.53%"],
    "Fairness Predictive Equality": ["91.99%", "99.10%", "95.82%", "68.02%", "71.45%", "89.43%", "78.03%"]
}

# 데이터프레임 생성
undersampled = pd.DataFrame(data)

# 결과 출력
undersampled
# Out:
#                  Model TPR at FPR=5% Fairness Predictive Equality
# 0  Logistic Regression        49.69%                       91.99%
# 1        Random Forest        44.96%                       99.10%
# 2    Gradient Boosting        52.05%                       95.82%
# 3        Decision Tree         0.00%                       68.02%
# 4          Naive Bayes        33.95%                       71.45%
# 5             LightGBM        52.68%                       89.43%
# 6              XGBoost        47.53%                       78.03%
